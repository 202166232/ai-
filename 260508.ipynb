# %% [markdown]
# <a href="https://colab.research.google.com/github/202166232/aiphyton/blob/main/260508.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 간단한 데이터프레임 만들기
data = {
    '이름': ['철수', '영희', '민수', '수지'],
    '나이': [25, 30, 22, 28],
    '도시': ['서울', '부산', '대구', '인천']
}
df = pd.DataFrame(data)

# 데이터프레임 출력
display(df)
